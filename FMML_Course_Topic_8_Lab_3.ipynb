# %% [markdown]
# <a href="https://colab.research.google.com/github/akhila-kalagarla/FMML_LAB_MODULES/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 04:09:13--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   193MB/s    in 0.4s
#
# 2024-03-31 04:09:15 (193 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2945 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 25629  1510.07320v1  We present a novel algorithm for estimating th...    cs
# 350    1705.09558v3  Generative adversarial networks (GANs) can imp...  stat
# 14300  1708.02691v3  This article concerns the expressive power of ...  stat
# 10817   1408.0043v1  Ranking over sets arise when users choose betw...    cs
# 27993  1705.02893v1  Epileptic seizures are caused by abnormal, ove...    cs
# ...             ...                                                ...   ...
# 5862    1206.6476v1  In recent years, the crucial importance of met...    cs
# 35249  cs/0205022v1  Information personalization is fertile ground ...    cs
# 33284   0902.1037v2  In this work we deal with the optimal design a...    cs
# 18434   1006.5511v2  Notions of core, support and inversion of a so...    cs
# 17884  cs/9412101v1  The vast amounts of on-line text now available...    cs
#
#                                                    title  year  \
# 25629                      Geometric Context from Videos  2015
# 350                                         Bayesian GAN  2017
# 14300  Universal Function Approximation by Deep Neura...  2017
# 10817  Learning From Ordered Sets and Applications in...  2014
# 27993  Multi Resolution LSTM For Long Term Prediction...  2017
# ...                                                  ...   ...
# 5862   Similarity Learning for Provably Accurate Spar...  2012
# 35249                       The Traits of the Personable  2002
# 33284  Optimal design and optimal control of structur...  2009
# 18434    Soft Approximations and uni-int Decision Making  2010
# 17884  Wrap-Up: a Trainable Discourse Module for Info...  1994
#
#                                                 keywords
# 25629  [algorithm, estimating, geometric, structure, ...
# 350    [generative, adversarial, implicitly, distribu...
# 14300  [expressive, activations, particularly, intere...
# 10817  [customized, investigate, combinatorics, parti...
# 27993  [epileptic, chronized, electrical, electrical,...
# ...                                                  ...
# 5862   [importance, algorithms, increasing, optimizin...
# 35249  [information, personalization, application, te...
# 33284  [structures, undergoing, rotations, correspond...
# 18434  [inversion, approximations, developed, granula...
# 17884  [available, information, extraction, unrestric...
#
# [5156 rows x 6 columns]

# %%
df['keywords']
# Out:
# 25629    [algorithm, estimating, geometric, structure, ...
# 350      [generative, adversarial, implicitly, distribu...
# 14300    [expressive, activations, particularly, intere...
# 10817    [customized, investigate, combinatorics, parti...
# 27993    [epileptic, chronized, electrical, electrical,...
#                                ...
# 17447    [structured, explicitly, compositionality, spe...
# 9438     [designing, informative, efficient, explorator...
# 2612     [variables, commonplace, statistically, comput...
# 3681     [approximate, posterior, distribution, variati...
# 3548     [practical, supervised, significant, artificia...
# Name: keywords, Length: 6445, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 9022 words.
# Out of those 4687 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="98599602-bcf5-4aa1-bee0-e8741d2b1b4a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("98599602-bcf5-4aa1-bee0-e8741d2b1b4a")) {                    Plotly.newPlot(                        "98599602-bcf5-4aa1-bee0-e8741d2b1b4a",                        [{"x":["extensive","alleviating","consisting","annotated","leveraging","geometric","structure","granularity","determine","homogeneity","unlabeled","achieving","framework","classifiers","algorithm","confidence","hierarchy","segmentation","decompose","examining","predictions","prediction","supervised","estimating","appearance","formulation","interventions","practical","generative","unsupervised","hamiltonian","posterior","discrimination","ensembles","parameters","including","adversarial","benchmarks","exploring","marginalize","straightforward","outperforming","quantitative","stochastic","candidate","performance","wasserstein","discriminator","generator","distributions","likelihood","expressive","interpretable","resulting","implicitly","particularly","approximate","approximation","interested","convexity","activations","necessary","functions","dimensional","following","arbitrarily","universal","arbitrary","particular","estimates","continuous","activation","representing","questions","observation","variables","demonstrate","challenging","discovering","metropolis","filtering","customized","investigate","combinatorics","inference","evaluated","collaborative","probabilistic","construct","efficiently","combinatorial","partitioning","procedure","competitive","applications","approaches","posteriors","benchmark","significantly","propagating","propagation","direction","sufficiently","responsive","resolution","discriminative","structures","predictor","electrical","associated","epileptic","outperform","alleviate","manifests","representation","accomplish","stimulation","vanishing","intervention","concludes","discussion","artificial","presented","methodologies","technologies","increasing","revolutionize","translation","combining","information","recurrent","narrowing","recognition","interpretability","transparent","application","complementary","understandable","combinations","topological","invariant","designing","considerations","operators","invariance","empirically","generalized","expression","generalization","architecture","parameterization","introduce","dimension","solutions","therefore","predicate","demonstrated","sophisticated","pointwise","importance","considerably","embedding","combination","relatively","revisiting","simplicity","algorithms","companies","probabilities","modification","accurately","technique","bootstrapping","intervals","increments","comparison","important","occurrences","mathematical","transport","regularized","factorized","automatically","partitions","simultaneously","motivating","evaluations","homogeneous","represented","empirical","variational","experimental","perspective","estimated","representations","probability","multiscale","instances","theoretically","clustering"],"y":[197,6,57,81,51,80,304,9,69,2,46,78,535,102,825,51,36,187,13,13,94,245,216,50,62,92,9,144,117,145,2,31,30,8,222,251,92,95,36,1,26,24,79,139,54,894,6,22,34,118,65,28,31,164,30,71,112,126,16,10,29,75,220,172,72,22,37,87,261,68,117,36,60,68,64,137,581,272,21,5,72,6,127,3,217,140,33,172,79,166,36,12,115,111,438,453,6,214,252,12,74,60,17,3,109,98,120,15,6,124,5,106,21,2,362,10,4,20,15,8,37,158,173,16,42,105,2,102,99,708,156,2,363,24,8,258,33,1,24,13,64,51,8,45,21,83,72,41,121,256,9,316,66,143,138,5,97,32,5,84,32,105,132,46,5,19,587,9,51,26,88,268,10,21,2,124,339,11,53,8,47,7,189,11,128,6,53,12,64,141,63,384,68,58,220,177,4,87,43,165],"type":"bar"},{"x":["extensive","alleviating","consisting","annotated ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4687,), (4687, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8324282389449186

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Sketch</span> <span style=''>based</span> <span style=''>Image</span> <span style='background-color:rgba(0, 255, 0, 0.525179856115108);'>Retrieval</span> <span style=''>from</span> <span style=''>Millions</span> <span style=''>of</span> <span style=''>Images</span> <span style=''>under</span> <span style=''>Rotation</span> <span style='background-color:rgba(0, 255, 0, 0.8053097345132743);'>Translation</span> <span style=''>and</span> <span style=''>Scale</span> <span style='background-color:rgba(0, 255, 0, 0.3406593406593406);'>Variations</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>Proliferation</span> <span style=''>of</span> <span style=''>touch</span> <span style=''>based</span> <span style=''>devices</span> <span style=''>has</span> <span style=''>made</span> <span style=''>sketch</span> <span style=''>based</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.525179856115108);'>retrieval</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>practical</span> <span style=''>While</span> <span style=''>many</span> <span style=''>methods</span> <span style=''>exist</span> <span style=''>for</span> <span style=''>sketch</span> <span style=''>based</span> <span style=''>object</span> <span style=''>detectionimage</span> <span style='background-color:rgba(0, 255, 0, 0.525179856115108);'>retrieval</span> <span style=''>on</span> <span style=''>small</span> <span style=''>datasets</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relatively</span> <span style=''>less</span> <span style=''>work</span> <span style=''>has</span> <span style=''>been</span> <span style=''>done</span> <span style=''>on</span> <span style=''>large</span> <span style=''>(web)</span> <span style=''>scale</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.525179856115108);'>retrieval</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>approach</span> <span style=''>for</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.525179856115108);'>retrieval</span> <span style=''>from</span> <span style=''>millions</span> <span style=''>of</span> <span style=''>images</span> <span style=''>based</span> <span style=''>on</span> <span style=''>user</span> <span style=''>drawn</span> <span style=''>sketches</span> <span style=''>Unlike</span> <span style=''>existing</span> <span style=''>methods</span> <span style=''>for</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>which</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sensitive</span> <span style=''>to</span> <span style=''>even</span> <span style='background-color:rgba(0, 255, 0, 0.8053097345132743);'>translation</span> <span style=''>or</span> <span style=''>scale</span> <span style='background-color:rgba(0, 255, 0, 0.3406593406593406);'>variations</span> <span style=''>our</span> <span style=''>method</span> <span style=''>handles</span> <span style=''>rotation</span> <span style='background-color:rgba(0, 255, 0, 0.8053097345132743);'>translation</span> <span style=''>scale</span> <span style=''>(ie</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>similarity</span> <span style=''>transformation)</span> <span style=''>and</span> <span style=''>small</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666666);'>deformations</span> <span style=''>The</span> <span style=''>object</span> <span style='background-color:rgba(0, 255, 0, 0.5714285714285715);'>boundaries</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>represented</span> <span style=''>as</span> <span style=''>chains</span> <span style=''>of</span>  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Fast</span> <span style=''>MCMC</span> <span style=''>sampling</span> <span style=''>for</span> <span style=''>Markov</span> <span style=''>jump</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style=''>time</span> <span style=''>Bayesian</span> <span style=''>networks</span> <br/><br/><span style=''>Markov</span> <span style=''>jump</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style=''>time</span> <span style=''>Bayesian</span> <span style=''>networks</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style=''>classes</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style=''>time</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dynamical</span> <span style=''>systems</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>tackle</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inferring</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unobserved</span> <span style=''>paths</span> <span style=''>in</span> <span style=''>these</span> <span style=''>models</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introducing</span> <span style=''>a</span> <span style=''>fast</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>auxiliary</span> <span style=''>variable</span> <span style=''>Gibbs</span> <span style=''>sampler</span> <span style=''>Our</span> <span style=''>approach</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>idea</span> <span style=''>of</span> <span style=''>uniformization</span> <span style=''>and</span> <span style=''>sets</span> <span style=''>up</span> <span style=''>a</span> <span style=''>Markov</span> <span style=''>chain</span> <span style=''>over</span> <span style=''>paths</span> <span style=''>by</span> <span style=''>sampling</span> <span style=''>a</span> <span style=''>finite</span> <span style=''>set</span> <span style=''>of</span> <span style=''>virtual</span> <span style=''>jump</span> <span style=''>times</span> <span style=''>and</span> <span style=''>then</span> <span style=''>running</span> <span style=''>a</span> <span style=''>standard</span> <span style=''>hidden</span> <span style=''>Markov</span> <span style=''>model</span> <span style=''>forward</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>filtering</span> <span style=''>backward</span> <span style=''>sampling</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>over</span> <span style=''>states</span> <span style=''>at</span> <span style=''>the</span> <span style=''>set</span> <span style=''>of</span> <span style=''>extant</span> <span style=''>and</span> <span style=''>virtual</span> <span style=''>jump</span> <span style=''>times</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significant</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computational</span> <span style=''>benefits</span> <span style=''>over</span> <span style=''>a</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>Gibbs</span> <span style=''>sampler</span> <span style=''>on</span> <span style=''>a</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span st ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Predictions</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statements</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decisions</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Prediction</span> <span style=''>is</span> <span style=''>a</span> <span style=''>complex</span> <span style=''>notion</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>different</span> <span style='background-color:rgba(255, 0, 0, 0.6000000000000001);'>predictors</span> <span style=''>(such</span> <span style=''>as</span> <span style=''>people</span> <span style=''>computer</span> <span style=''>programs</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style=''>theories)</span> <span style=''>can</span> <span style=''>pursue</span> <span style=''>very</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>different</span> <span style=''>goals</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>I</span> <span style=''>will</span> <span style=''>review</span> <span style=''>some</span> <span style=''>popular</span> <span style=''>kinds</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style=''>and</span> <span style=''>argue</span> <span style=''>that</span> <span style=''>the</span> <span style=''>theory</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>competitive</span> <span style=''>on</span> <span style=''>line</span> <span style=''>learning</span> <span style=''>can</span> <span style=''>benefit</span> <span style=''>from</span> <span style=''>the</span> <span style=''>kinds</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style=''>that</span> <span style=''>are</span> <span style=''>now</span> <span style=''>foreign</span> <span style=''>to</span> <span style=''>it</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Deep</span> <span style=''>Learning</span> <span style=''>Methods</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Efficient</span> <span style=''>Large</span> <span style=''>Scale</span> <span style=''>Video</span> <span style=''>Labeling</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>solution</span> <span style=''>to</span> <span style=''>Google</span> <span style=''>Cloud</span> <span style=''>and</span> <span style=''>YouTube</span> <span style=''>8M</span> <span style=''>Video</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Understanding</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Challenge</span> <span style=''>that</span> <span style=''>ranked</span> <span style=''>5th</span> <span style=''>place</span> <span style=''>The</span> <span style=''>proposed</span> <span style=''>model</span> <span style=''>is</span> <span style=''>an</span> <span style=''>ensemble</span> <span style=''>of</span> <span style=''>three</span> <span style=''>model</span> <span style=''>families</span> <span style=''>two</span> <span style=''>frame</span> <span style=''>level</span> <span style=''>and</span> <span style=''>one</span> <span style=''>video</span> <span style=''>level</span> <span style=''>The</span> <span style=''>training</span> <span style=''>was</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performed</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>augmented</span> <span style=''>dataset</span> <span style=''>with</span> <span style=''>cross</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>validation</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	challenging (0.09700427960057062)
# 	experimental (0.1369472182596291)
# 	representation (0.1291012838801712)
# 	segmentation (0.06669044222539229)
# 	architecture (0.0912981455064194)
# 	detection (0.11626248216833096)
# 	information (0.2524964336661912)
# 	different (0.27282453637660486)
# 	recognition (0.12945791726105563)
# 	convolutional (0.13088445078459343)
#
# Some Statistics words are:
# 	stochastic (0.1377551020408163)
# 	theoretical (0.1475340136054422)
# 	variables (0.14285714285714285)
# 	estimation (0.17049319727891157)
# 	statistical (0.15773809523809523)
# 	algorithm (0.3958333333333333)
# 	distribution (0.1909013605442177)
# 	dimensional (0.18877551020408162)
# 	regression (0.1683673469387755)
# 	inference (0.2108843537414966)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="61d848a3-301f-4ae4-864d-1e21cd1ac5ac" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("61d848a3-301f-4ae4-864d-1e21cd1ac5ac")) {                    Plotly.newPlot(                        "61d848a3-301f-4ae4-864d-1e21cd1ac5ac",                        [{"x":["extensive","alleviating","consisting","annotated","leveraging","geometric","structure","granularity","determine","homogeneity","unlabeled","achieving","framework","classifiers","algorithm","confidence","hierarchy","segmentation","decompose","examining","predictions","prediction","supervised","estimating","appearance","formulation","interventions","practical","generative","unsupervised","hamiltonian","posterior","discrimination","ensembles","parameters","including","adversarial","benchmarks","exploring","marginalize","straightforward","outperforming","quantitative","stochastic","candidate","performance","wasserstein","discriminator","generator","distributions","likelihood","expressive","interpretable","resulting","implicitly","particularly","approximate","approximation","interested","convexity","activations","necessary","functions","dimensional","following","arbitrarily","universal","arbitrary","particular","estimates","continuous","activation","representing","questions","observation","variables","demonstrate","challenging","discovering","metropolis","filtering","customized","investigate","combinatorics","inference","evaluated","collaborative","probabilistic","construct","efficiently","combinatorial","partitioning","procedure","competitive","applications","approaches","posteriors","benchmark","significantly","propagating","propagation","direction","sufficiently","responsive","resolution","discriminative","structures","predictor","electrical","associated","epileptic","outperform","alleviate","manifests","representation","accomplish","stimulation","vanishing","intervention","concludes","discussion","artificial","presented","methodologies","technologies","increasing","revolutionize","translation","combining","information","recurrent","narrowing","recognition","interpretability","transparent","application","complementary","understandable","combinations","topological","invariant","designing","considerations","operators","invariance","empirically","generalized","expression","generalization","architecture","parameterization","introduce","dimension","solutions","therefore","predicate","demonstrated","sophisticated","pointwise","importance","considerably","embedding","combination","relatively","revisiting","simplicity","algorithms","companies","probabilities","modification","accurately","technique","bootstrapping","intervals","increments","comparison","important","occurrences","mathematical","transport","regularized","factorized","automatically","partitions","simultaneously","motivating","evaluations","homogeneous","represented","empirical","variational","experimental","perspective","estimated","representations","probability","multiscale","instances","theoretically","clustering","kernelized","databases","investigates","available","relationship","additionally","warehouse","management","customers","structural","supporting","retaining","corporate","attracting","techniques","knowledge","attention","adaptation","mechanism","additional","outperforms","effective","developed","statistical","alignment","descriptions","overcoming","formulated","diversity","possibilistic","constraint","diagnosis","widespread","segmenting","measurement","modifying","influenced","conventional","conducted","presently","tomography","eliminated","radiography","membership","processing","essential","consequent","limitation","experiments","segmented","objective","resonance","corrupted","corresponding","identifie ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	changepoint
# 	changepoints
# 	misspecified
# 	procrustes
# 	semiparametric
# 	schizophrenia
# 	methylation
# 	consortium
# 	lightspeed
# 	subgaussian
# 	debiasing
# 	forecasted
# 	thresholded
# 	sparsifying
# 	ultrametric
# 	pessimistic
# 	conformalized
# 	linearization
# 	correntropy
# 	sharpness
# Some words which never appear in Statistics papers:
# 	responsive
# 	warehouse
# 	corporate
# 	possibilistic
# 	presently
# 	radiography
# 	psychology
# 	nondeterministic
# 	syntactic
# 	propositional
# 	affordance
# 	autonomously
# 	abstraction
# 	attachment
# 	chromosome
# 	interclass
# 	intraclass
# 	avoidance
# 	assistant
# 	receivers

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.055581018730712e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.813033359193173
